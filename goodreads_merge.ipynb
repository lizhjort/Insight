# %% [markdown]
# <a href="https://colab.research.google.com/github/lizhjort/Insight/blob/master/goodreads_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb

# %%
goodreads = pd.read_pickle('/content/gdrive/My Drive/insight_data/goodreads.pkl.gz')

# %%
data_with_checkouts = pd.read_pickle('/content/gdrive/My Drive/insight_data/data_10_col.pkl.gz')

# %%
goodreads.shape
# Out:
# (90216, 9)

# %%
goodreads.head()
# Out:
#          isbn        isbn13  ...  work_text_reviews_count  average_rating
# 0   316273880  9.780320e+12  ...                     1837            4.22
# 1  1101870052  9.781100e+12  ...                       37            4.04
# 2   316262870  9.780320e+12  ...                       88            3.75
# 3  1410499642  9.781410e+12  ...                    40345            4.32
# 4    62645226  9.780060e+12  ...                     6761            3.93
#
# [5 rows x 9 columns]

# %%
goodreads = goodreads.drop(['work_ratings_count', 'work_reviews_count', 'work_text_reviews_count'], axis=1)

# %%
data_with_checkouts.head()
# Out:
#    BibNumber CheckoutDate  ...  PublicationYear        isbn
# 0      10143   2017-09-03  ...           c1997.  082220911X
# 1      10143   2017-09-10  ...           c1997.  082220911X
# 2      10143   2017-09-17  ...           c1997.  082220911X
# 3      10143   2017-09-24  ...           c1997.  082220911X
# 4      10143   2017-10-01  ...           c1997.  082220911X
#
# [5 rows x 11 columns]

# %%
data = pd.merge(data_with_checkouts, goodreads, on=['isbn'], how='left')

# %%
data
# Out:
#          BibNumber CheckoutDate  ...  text_reviews_count  average_rating
# 0            10143   2017-09-03  ...                 5.0            3.82
# 1            10143   2017-09-10  ...                 5.0            3.82
# 2            10143   2017-09-17  ...                 5.0            3.82
# 3            10143   2017-09-24  ...                 5.0            3.82
# 4            10143   2017-10-01  ...                 5.0            3.82
# 5            10143   2017-10-08  ...                 5.0            3.82
# 6            10143   2017-10-15  ...                 5.0            3.82
# 7            10143   2017-10-22  ...                 5.0            3.82
# 8            10143   2017-10-29  ...                 5.0            3.82
# 9            10143   2017-11-05  ...                 5.0            3.82
# 10           10143   2017-11-12  ...                 5.0            3.82
# 11           10143   2017-11-19  ...                 5.0            3.82
# ...

# %%
data.isnull().sum()
# Out:
# BibNumber                        0
# CheckoutDate                     0
# CheckoutCount                    0
# CheckoutCount1WeekPrev           1
# CheckoutCount2WeekPrev           2
# CheckoutCountNextWeek            2
# Genre                      1116279
# Title                            0
# ISBN                        815238
# PublicationYear                  0
# isbn                        815238
# isbn13                     3413658
# ratings_count              3397941
# reviews_count              3397941
# text_reviews_count         3397941
# work_ratings_count         3397941
# work_reviews_count         3397941
# work_text_reviews_count    3397941
# average_rating             3397941
# dtype: int64

# %%
data.to_pickle('/content/gdrive/My Drive/insight_data/data_11_col.pkl.gz')
